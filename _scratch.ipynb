# %%
ls
# Out:
# README.md                data/                    precompiled_wd/
# Supplementary_File1.csv  eimd_analysis.ipynb      scripts/
# _scratch.ipynb           eimd_data-only.ipynb     wd/

# %%
cd ..
# Out:
# /Users/sr320/git-repos/eimd-sswd

# %%
# !head -2 Supplementary_File1.csv
# Out:
# Contig,spID,e-value,log2FoldChange,padj,Protein names,Enriched GO TermS
# Phel_clc_contig_2240,Q4JIM4,1.00E-125,1.798826816,0.00873868,Presenilin-1 (PS-1) (EC 3.4.23.-) [Cleaved into: Presenilin-1 NTF subunit; Presenilin-1 CTF subunit],activation of immune response; biological adhesion; cell adhesion; cell surface receptor linked signal transduction; immune response; positive regulation of immune response; positive regulation of immune system process

# %%
# !fgrep -c ">" data/*
# Out:
# data/Phel_countdata.txt:0
# data/Phel_transcriptome.fasta:29476

# %%
# !head data/*
# Out:
# ==> data/Phel_countdata.txt <==
# Feature ID	Treated_FHL - Total gene reads	Treated_PH - Total gene reads	Treated_L - Total gene reads	Control_FHL - Total gene reads	Control_DB - Total gene reads	Control_PH - Total gene reads
# Phel_contig_1	168	37	8	89	28	38
# Phel_contig_10	9518	2752	839	22	42	180
# Phel_contig_100	260	565	413	616	1234	6104
# Phel_contig_1000	2043	3842	3070	4311	8527	31946
# Phel_contig_10000	9	12	13	32	21	211
# Phel_contig_10001	44	225	89	90	54	365
# Phel_contig_10002	38	61	80	185	478	1267
# Phel_contig_10003	9	29	20	17	29	186
# Phel_contig_10004	8	25	6	4	19	92
#
# ==> data/Phel_transcriptome.fasta <==
# >Phel_contig_1
# ...
# >Phel_contig_10
# ...
# >Phel_contig_100
# ...
# >Phel_contig_1000
# ...
# >Phel_contig_10000
# ...

# %%
# !head -2 Supplementary_File1.csv
# Out:
# Contig,spID,e-value,log2FoldChange,padj,Protein names,Enriched GO TermS
# Phel_clc_contig_2240,Q4JIM4,1.00E-125,1.798826816,0.00873868,Presenilin-1 (PS-1) (EC 3.4.23.-) [Cleaved into: Presenilin-1 NTF subunit; Presenilin-1 CTF subunit],activation of immune response; biological adhesion; cell adhesion; cell surface receptor linked signal transduction; immune response; positive regulation of immune response; positive regulation of immune system process

# %% [markdown]
# ## covert , to tab

# %%
# !tr ',' "\t" \
<Supplementary_File1.csv> \
Supplementary_File1.tab

# %%
# !head -2 Supplementary_File1.tab
# Out:
# Contig	spID	e-value	log2FoldChange	padj	Protein names	Enriched GO TermS
# Phel_clc_contig_2240	Q4JIM4	1.00E-125	1.798826816	0.00873868	Presenilin-1 (PS-1) (EC 3.4.23.-) [Cleaved into: Presenilin-1 NTF subunit; Presenilin-1 CTF subunit]	activation of immune response; biological adhesion; cell adhesion; cell surface receptor linked signal transduction; immune response; positive regulation of immune response; positive regulation of immune system process

# %%
# !sed 's/TermS/Terms/g' \
Supplementary_File1-b.tab > Supplemental_File-01.tab

# %%
# !head -2 Supplementary_File1-b.tab
# Out:
# Contig	spID	e-value	log2FoldChange	padj	Protein names	Enriched GO TermS
# Phel_contig_2240	Q4JIM4	1.00E-125	1.798826816	0.00873868	Presenilin-1 (PS-1) (EC 3.4.23.-) [Cleaved into: Presenilin-1 NTF subunit; Presenilin-1 CTF subunit]	activation of immune response; biological adhesion; cell adhesion; cell surface receptor linked signal transduction; immune response; positive regulation of immune response; positive regulation of immune system process

# %%
# !head Supplemental_File-01.tab
# Out:
# Contig	spID	e-value	log2FoldChange	padj	Protein names	Enriched GO Terms
# Phel_contig_2240	Q4JIM4	1.00E-125	1.798826816	0.00873868	Presenilin-1 (PS-1) (EC 3.4.23.-) [Cleaved into: Presenilin-1 NTF subunit; Presenilin-1 CTF subunit]	activation of immune response; biological adhesion; cell adhesion; cell surface receptor linked signal transduction; immune response; positive regulation of immune response; positive regulation of immune system process
# ...
